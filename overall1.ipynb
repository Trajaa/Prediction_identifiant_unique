# %%
import pandas as pd
data2 = pd.read_csv('C:/Users/hp/Desktop/prj_pfe_inwi/top_hier_bts_overall_d1_10000_chiffre.csv')

# %%
# Compter le nombre d'occurrences des valeurs distinctes dans chaque colonne
for column in data2.columns:
    value_counts = data2[column].value_counts()
    print(f"Colonne '{column}':")
    print(value_counts)
    print()
# Out:
# Colonne 'Unnamed: 0':
# 0        1
# 66650    1
# 66672    1
# 66671    1
# 66670    1
#         ..
# 33331    1
# 33330    1
# 33329    1
# 33328    1
# 99999    1
# Name: Unnamed: 0, Length: 100000, dtype: int64
#
# Colonne 'date_debut':
# 2021-12-01    100000
# Name: date_debut, dtype: int64
#
# Colonne 'mdn':
# 479e5ba06010b11c6618fff004e01a99    1
# ca8ff091831f7777dd418a098df3af41    1
# e6290f091b37bbd32b543b82a51bd5a9    1
# 08d94a8b9da98459791cd41a73990b0f    1
# 7e5bb73a4c21308a64e9985236c0f3c8    1
#                                    ..
# a0b90ef4d11b13eaf75ad97859d994f3    1
# baa31104b2ea5d5d02bcd5e446cf26d3    1
# 8d546f12bd663fa012836652fbe62956    1
# ad8c06ac00757bf98e1f917955dfbd5f    1
# 12a45628aee16fa9a46b5f4fc197a9ba    1
# Name: mdn, Length: 100000, dtype: int64
#
# Colonne 'imsi':
# 7f723cf242e408c9ae33705362d3229d    1
# d1c00ec5f67d2d5a90fbef1c57717395    1
# 0048434ca9ef851144f23d16d72e3c5e    1
# 5be91c7c5748aced98f6854608b225cc    1
# ...

# %%
data2= data2.drop(data2.columns[0], axis=1) 
print(data2.columns)
# Out:
# Index(['date_debut', 'mdn', 'imsi', 'imei', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'segment', 'type_jour',
#        'princp_data_vol_jour_octets', 'princp_data_vol_jour_cell',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_bts',
#        'princp_data_vol_jour_ville', 'princp_data_vol_jour_region',
#        'princp_data_vol_jour_province', 'princp_data_vol_soir_octets',
#        'princp_data_vol_soir_cell', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_bts', 'princp_data_vol_soir_ville',
#        'princp_data_vol_soir_region', 'princp_data_vol_soir_province',
#        'princp_data_vol_nuit_octets', 'princp_data_vol_nuit_cell',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_bts',
#        'princp_data_vol_nuit_ville', 'princp_data_vol_nuit_region',
#        'princp_data_vol_nuit_province', 'princp_data_vol_total_octets',
# ...

# %%
import numpy as np
data2['princp_data_vol_jour_octets'] = np.log(data2['princp_data_vol_jour_octets'] +1)
data2['princp_data_vol_soir_octets'] = np.log(data2['princp_data_vol_soir_octets']+1)
data2['princp_data_vol_nuit_octets'] = np.log(data2['princp_data_vol_nuit_octets']+1)
data2['princp_data_vol_total_octets'] = np.log(data2['princp_data_vol_total_octets']+1)
data2['princp_voix_dur_jour_minutes'] = np.log(data2['princp_voix_dur_jour_minutes']+1)
data2['princp_voix_dur_soir_minutes'] = np.log(data2['princp_voix_dur_soir_minutes']+1) 
data2['princp_voix_dur_nuit_minutes'] = np.log(data2['princp_voix_dur_nuit_minutes']+1) 
data2['princp_voix_dur_total_minutes'] = np.log(data2['princp_voix_dur_total_minutes']+1)
data2['princp_vol_actv'] = np.log(data2['princp_vol_actv']+1)

# %%
columns_to_drop1 =['date_debut',"imei",'type_jour','segment','princp_actv_region','idnt_date']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_cell', 'princp_data_vol_jour_secteur',
#        'princp_data_vol_jour_bts', 'princp_data_vol_jour_ville',
#        'princp_data_vol_jour_region', 'princp_data_vol_jour_province',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_cell',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_bts',
#        'princp_data_vol_soir_ville', 'princp_data_vol_soir_region',
#        'princp_data_vol_soir_province', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_cell', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_bts', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_nuit_region', 'princp_data_vol_nuit_province',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_cell',
# ...

# %%
columns_to_drop1=['princp_data_vol_jour_cell', 'princp_data_vol_jour_bts', 'princp_data_vol_jour_region', 'princp_data_vol_jour_province']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_cell',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_bts',
#        'princp_data_vol_soir_ville', 'princp_data_vol_soir_region',
#        'princp_data_vol_soir_province', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_cell', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_bts', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_nuit_region', 'princp_data_vol_nuit_province',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_cell',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_bts',
#        'princp_data_vol_total_ville', 'princp_data_vol_total_region',
# ...

# %%
columns_to_drop1=['princp_data_vol_soir_cell', 'princp_data_vol_soir_bts', 'princp_data_vol_soir_region', 'princp_data_vol_soir_province' ]
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_cell', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_bts', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_nuit_region', 'princp_data_vol_nuit_province',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_cell',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_bts',
#        'princp_data_vol_total_ville', 'princp_data_vol_total_region',
#        'princp_data_vol_total_province', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_cell', 'princp_voix_dur_jour_secteur',
# ...

# %%
columns_to_drop1=['princp_data_vol_nuit_cell', 'princp_data_vol_nuit_bts', 'princp_data_vol_nuit_region', 'princp_data_vol_nuit_province']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_cell',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_bts',
#        'princp_data_vol_total_ville', 'princp_data_vol_total_region',
#        'princp_data_vol_total_province', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_cell', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_bts', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_jour_region', 'princp_voix_dur_jour_province',
# ...

# %%
columns_to_drop1=['princp_data_vol_total_cell', 'princp_data_vol_total_bts', 'princp_data_vol_total_region', 'princp_data_vol_total_province']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_cell', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_bts', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_jour_region', 'princp_voix_dur_jour_province',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_cell',
#        'princp_voix_dur_soir_secteur', 'princp_voix_dur_soir_bts',
# ...

# %%
columns_to_drop1=['princp_voix_dur_jour_cell', 'princp_voix_dur_jour_bts', 'princp_voix_dur_jour_region', 'princp_voix_dur_jour_province']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_secteur', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_cell',
#        'princp_voix_dur_soir_secteur', 'princp_voix_dur_soir_bts',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_soir_region',
#        'princp_voix_dur_soir_province', 'princp_voix_dur_nuit_minutes',
# ...

# %%
columns_to_drop1=['princp_voix_dur_soir_cell','princp_voix_dur_soir_bts', 'princp_voix_dur_soir_region', 'princp_voix_dur_soir_province']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_secteur', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_minutes',
#        'princp_voix_dur_nuit_cell', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_bts', 'princp_voix_dur_nuit_ville',
# ...

# %%
columns_to_drop1=['princp_voix_dur_nuit_cell', 'princp_voix_dur_nuit_bts', 'princp_voix_dur_nuit_region', 'princp_voix_dur_nuit_province' ]
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_secteur', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_minutes',
#        'princp_voix_dur_nuit_secteur', 'princp_voix_dur_nuit_ville',
#        'princp_voix_dur_total_minutes', 'princp_voix_dur_total_cell',
# ...

# %%
columns_to_drop1=['princp_voix_dur_total_cell', 'princp_voix_dur_total_bts', 'princp_voix_dur_total_region', 'princp_voix_dur_total_province' ]
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'gamme', 'marche', 'princp_data_vol_jour_octets',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_octets', 'princp_data_vol_soir_secteur',
#        'princp_data_vol_soir_ville', 'princp_data_vol_nuit_octets',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_secteur', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_minutes',
#        'princp_voix_dur_nuit_secteur', 'princp_voix_dur_nuit_ville',
#        'princp_voix_dur_total_minutes', 'princp_voix_dur_total_secteur',
# ...

# %%
columns_to_drop1=['princp_actv_total_cell', 'princp_actv_total_bts','gamme','marche']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_octets', 'princp_data_vol_jour_secteur',
#        'princp_data_vol_jour_ville', 'princp_data_vol_soir_octets',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_octets', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_ville', 'princp_data_vol_total_octets',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_ville',
#        'princp_voix_dur_jour_minutes', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_minutes',
#        'princp_voix_dur_soir_secteur', 'princp_voix_dur_soir_ville',
#        'princp_voix_dur_nuit_minutes', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
# ...

# %%
columns_to_drop1=["princp_actv_province"]
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'imsi', 'idnt_contrat', 'idnt_client_crm',
#        'idnt_compte_facturation', 'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_octets', 'princp_data_vol_jour_secteur',
#        'princp_data_vol_jour_ville', 'princp_data_vol_soir_octets',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_octets', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_ville', 'princp_data_vol_total_octets',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_ville',
#        'princp_voix_dur_jour_minutes', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_minutes',
#        'princp_voix_dur_soir_secteur', 'princp_voix_dur_soir_ville',
#        'princp_voix_dur_nuit_minutes', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
# ...

# %%
columns_to_drop1=["imsi"]
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'idnt_contrat', 'idnt_client_crm', 'idnt_compte_facturation',
#        'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_octets', 'princp_data_vol_jour_secteur',
#        'princp_data_vol_jour_ville', 'princp_data_vol_soir_octets',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_octets', 'princp_data_vol_nuit_secteur',
#        'princp_data_vol_nuit_ville', 'princp_data_vol_total_octets',
#        'princp_data_vol_total_secteur', 'princp_data_vol_total_ville',
#        'princp_voix_dur_jour_minutes', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_minutes',
#        'princp_voix_dur_soir_secteur', 'princp_voix_dur_soir_ville',
#        'princp_voix_dur_nuit_minutes', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
#        'princp_voix_dur_total_secteur', 'princp_voix_dur_total_ville',
# ...

# %%
columns_to_drop1=['princp_data_vol_jour_octets','princp_data_vol_soir_octets','princp_data_vol_nuit_octets']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'idnt_contrat', 'idnt_client_crm', 'idnt_compte_facturation',
#        'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_minutes',
#        'princp_voix_dur_jour_secteur', 'princp_voix_dur_jour_ville',
#        'princp_voix_dur_soir_minutes', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_minutes',
#        'princp_voix_dur_nuit_secteur', 'princp_voix_dur_nuit_ville',
#        'princp_voix_dur_total_minutes', 'princp_voix_dur_total_secteur',
#        'princp_voix_dur_total_ville', 'princp_actv_total_secteur',
#        'princp_actv_ville', 'princp_vol_actv', 'princp_vol_actv_unit'],
# ...

# %%
columns_to_drop1=['princp_voix_dur_soir_minutes','princp_voix_dur_nuit_minutes','princp_voix_dur_jour_minutes']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'idnt_contrat', 'idnt_client_crm', 'idnt_compte_facturation',
#        'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
#        'princp_voix_dur_total_secteur', 'princp_voix_dur_total_ville',
#        'princp_actv_total_secteur', 'princp_actv_ville', 'princp_vol_actv',
#        'princp_vol_actv_unit'],
#       dtype='object')

# %%
# Compter le nombre d'occurrences des valeurs distinctes dans chaque colonne
for column in data2.columns:
    value_counts = data2[column].value_counts()
    print(f"Colonne '{column}':")
    print(value_counts)
    print()
# Out:
# Colonne 'mdn':
# 479e5ba06010b11c6618fff004e01a99    1
# ca8ff091831f7777dd418a098df3af41    1
# e6290f091b37bbd32b543b82a51bd5a9    1
# 08d94a8b9da98459791cd41a73990b0f    1
# 7e5bb73a4c21308a64e9985236c0f3c8    1
#                                    ..
# a0b90ef4d11b13eaf75ad97859d994f3    1
# baa31104b2ea5d5d02bcd5e446cf26d3    1
# 8d546f12bd663fa012836652fbe62956    1
# ad8c06ac00757bf98e1f917955dfbd5f    1
# 12a45628aee16fa9a46b5f4fc197a9ba    1
# Name: mdn, Length: 100000, dtype: int64
#
# Colonne 'idnt_contrat':
# 510bcb0cebfdaf7a6b886aeea65dc890    1
# ca8b461d81435ce8685687e5e8567ef3    1
# ae160dc37c0680a8b9a529c32f08e270    1
# f3578b4530888ffff0e480a325091fb1    1
# ff4d04921229361840f52be07eb16723    1
#                                    ..
# 5ca62d7a96456e437d36b97ee952eb27    1
# 0494697c01c3e205b075afeeb7be7252    1
# 05e412ae4e77b28c5c1d9094ccb81387    1
# 66eee92f6bdeb8cfb60c3ca8ac5e39af    1
# 797c90f3a9640201bc5f84ee61146dff    1
# ...

# %%
print(data2.columns)
# Out:
# Index(['mdn', 'idnt_contrat', 'idnt_client_crm', 'idnt_compte_facturation',
#        'idnt_profil', 'desc_profil', 'sous_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
#        'princp_voix_dur_total_secteur', 'princp_voix_dur_total_ville',
#        'princp_actv_total_secteur', 'princp_actv_ville', 'princp_vol_actv',
#        'princp_vol_actv_unit'],
#       dtype='object')

# %%
columns_to_drop1=['idnt_contrat','idnt_profil','sous_profil']
data2= data2.drop(columns=columns_to_drop1)
print(data2.columns)
# Out:
# Index(['mdn', 'idnt_client_crm', 'idnt_compte_facturation', 'desc_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_minutes',
#        'princp_voix_dur_total_secteur', 'princp_voix_dur_total_ville',
#        'princp_actv_total_secteur', 'princp_actv_ville', 'princp_vol_actv',
#        'princp_vol_actv_unit'],
#       dtype='object')

# %%
voice_overall = data2.loc[data2['princp_vol_actv_unit'] == 'minutes']
data_overall = data2.loc[data2['princp_vol_actv_unit'] == 'bytes']
print("Voice overall:")
print(voice_overall)
print("Data overall:")
print(data_overall)
# Out:
# Voice overall:
#                                     mdn                   idnt_client_crm  \
# 2      0adf7cb1e06a2572a658ef4b5d9b0861  f198a2ee467012e0366014da12557af9
# 3      24316ae30425c7c0e29d904b291361c6  078c3bda9e5a8201c8f536acad01633b
# 9      645e7e2ef1d592aa12d7fd60cfd39593  61c755c4df266c44f6ac3ca8fe110056
# 12     ed3c2efd5f89dfd20486b68da9a85bbf  6b07d8039c2499f7adef79be688b6249
# 15     21eb1fcc8ff94fc33d28e7a894fa8b94  171693dc27a2af89f862d4c85c1bd2cd
# ...                                 ...                               ...
# 99988  b6d775143352379707ebbf6685ed5b6e  68862b3d2a2597c32e83ce348733b7ac
# 99990  36908e4212e24b6614b61ef6b2e59720  1c4ccbb779bc5816b8c46abce03a89ce
# 99995  912b4be4bc954d5abfb07ff8731fb4f8  3000423a505e34d9062da576a1310c0e
# 99996  ca6e9d9a4151a4b7d8ac99931589ace5  29cc84edb530a71a17be9b34120226e1
# 99997  ec3f8165a9cd6b6e1dba6735ed41bec0  98efd16c2aca33eb3454827d32a29aa5
#
# ...

# %%
colonnes_manquantes = data_overall.columns[data_overall.isnull().any()].tolist()

# Afficher les noms des colonnes avec des valeurs manquantes
print("Colonnes avec des valeurs manquantes :")
for colonne in colonnes_manquantes:
    print(colonne)
# Out:
# Colonnes avec des valeurs manquantes :
# princp_voix_dur_total_minutes

# %%
columns_to_drop1=['princp_voix_dur_total_minutes']
data_overall= data_overall.drop(columns=columns_to_drop1)
print(data_overall.columns)
# Out:
# Index(['mdn', 'idnt_client_crm', 'idnt_compte_facturation', 'desc_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_secteur',
#        'princp_voix_dur_total_ville', 'princp_actv_total_secteur',
#        'princp_actv_ville', 'princp_vol_actv', 'princp_vol_actv_unit'],
#       dtype='object')

# %%
print(data_overall['princp_vol_actv_unit'])
# Out:
# 0        bytes
# 1        bytes
# 4        bytes
# 5        bytes
# 6        bytes
#          ...
# 99992    bytes
# 99993    bytes
# 99994    bytes
# 99998    bytes
# 99999    bytes
# Name: princp_vol_actv_unit, Length: 65880, dtype: object

# %%
columns_to_drop1=['princp_vol_actv_unit']
data_overall= data_overall.drop(columns=columns_to_drop1)
voice_overall= voice_overall.drop(columns=columns_to_drop1)
print(data_overall.columns)
print(voice_overall.columns)
# Out:
# Index(['mdn', 'idnt_client_crm', 'idnt_compte_facturation', 'desc_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_secteur',
#        'princp_voix_dur_total_ville', 'princp_actv_total_secteur',
#        'princp_actv_ville', 'princp_vol_actv'],
#       dtype='object')
# Index(['mdn', 'idnt_client_crm', 'idnt_compte_facturation', 'desc_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
# ...

# %%
data_overall.to_csv('C:/Users/hp/Desktop/prj_pfe_inwi/data_overall.csv', index=False)
voice_overall.to_csv('C:/Users/hp/Desktop/prj_pfe_inwi/voice_overall.csv', index=False)

# %%
print(data_overall.columns)
# Out:
# Index(['mdn', 'idnt_client_crm', 'idnt_compte_facturation', 'desc_profil',
#        'princp_data_vol_jour_secteur', 'princp_data_vol_jour_ville',
#        'princp_data_vol_soir_secteur', 'princp_data_vol_soir_ville',
#        'princp_data_vol_nuit_secteur', 'princp_data_vol_nuit_ville',
#        'princp_data_vol_total_octets', 'princp_data_vol_total_secteur',
#        'princp_data_vol_total_ville', 'princp_voix_dur_jour_secteur',
#        'princp_voix_dur_jour_ville', 'princp_voix_dur_soir_secteur',
#        'princp_voix_dur_soir_ville', 'princp_voix_dur_nuit_secteur',
#        'princp_voix_dur_nuit_ville', 'princp_voix_dur_total_secteur',
#        'princp_voix_dur_total_ville', 'princp_actv_total_secteur',
#        'princp_actv_ville', 'princp_vol_actv'],
#       dtype='object')

# %%
print(data_overall['princp_vol_actv'])
# Out:
# 0        19.786493
# 1        16.820786
# 4        22.386278
# 5         7.113956
# 6        20.039328
#            ...
# 99992    12.003859
# 99993    19.494730
# 99994     0.000000
# 99998    17.802808
# 99999    18.449121
# Name: princp_vol_actv, Length: 65880, dtype: float64

# %%
columns_to_drop1=['princp_voix_dur_total_secteur','princp_voix_dur_total_ville','princp_voix_dur_nuit_ville','princp_voix_dur_nuit_secteur','princp_voix_dur_soir_ville','princp_voix_dur_soir_secteur','princp_voix_dur_jour_ville','princp_voix_dur_jour_secteur']
data_overall= data_overall.drop(columns=columns_to_drop1)
